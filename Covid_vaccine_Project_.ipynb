# %% [markdown]
# <a href="https://colab.research.google.com/github/jay0597/Project---103/blob/main/Covid_vaccine_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %% [markdown]
# # Canada Vaccination Data

# %%
Canada_df=pd.read_csv('/content/gdrive/MyDrive/103 Project/Canada.csv')

# %%
Canada_df
# Out:
#            date  ...                                       vaccine
# 0    2020-12-14  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 1    2020-12-15  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 2    2020-12-16  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 3    2020-12-17  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 4    2020-12-18  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# ..          ...  ...                                           ...
# 317  2021-10-27  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 318  2021-10-28  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 319  2021-10-29  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 320  2021-10-30  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 321  2021-10-31  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
#
# [322 rows x 8 columns]

# %% [markdown]
# **Removed the source_url column from the dataframe as it just stores the same links to destination.**

# %%
Canada_df.drop('source_url', axis=1, inplace=True)

# %%
Canada_df
# Out:
#            date  ...                                       vaccine
# 0    2020-12-14  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 1    2020-12-15  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 2    2020-12-16  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 3    2020-12-17  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 4    2020-12-18  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# ..          ...  ...                                           ...
# 317  2021-10-27  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 318  2021-10-28  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 319  2021-10-29  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 320  2021-10-30  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 321  2021-10-31  ...  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
#
# [322 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
Canada_df.columns
# Out:
# Index(['date', 'total_vaccinations', 'people_fully_vaccinated',
#        'total_boosters', 'people_vaccinated', 'location', 'vaccine'],
#       dtype='object')

# %%
Canada_df.boxplot(column=['total_vaccinations'])

# %% [markdown]
# #UKRAINE Vaccination Data

# %%
Ukraine_df=pd.read_csv('/content/gdrive/MyDrive/103 Project/Ukraine.csv')

# %%
Ukraine_df
# Out:
#     location        date  ... people_fully_vaccinated total_boosters
# 0    Ukraine  2021-02-24  ...                       0            NaN
# 1    Ukraine  2021-02-25  ...                       0            NaN
# 2    Ukraine  2021-02-26  ...                       0            NaN
# 3    Ukraine  2021-02-27  ...                       0            NaN
# 4    Ukraine  2021-03-01  ...                       0            NaN
# ..       ...         ...  ...                     ...            ...
# 233  Ukraine  2021-10-27  ...                 7217383            NaN
# 234  Ukraine  2021-10-28  ...                 7292521            NaN
# 235  Ukraine  2021-10-29  ...                 7377032            NaN
# 236  Ukraine  2021-10-30  ...                 7421546            NaN
# 237  Ukraine  2021-10-31  ...                 7449818            NaN
#
# [238 rows x 8 columns]

# %%
Ukraine_df.drop('source_url', axis=1, inplace=True)

# %%
Ukraine_df
# Out:
#     location        date  ... people_fully_vaccinated  total_boosters
# 0    Ukraine  2021-02-24  ...                       0             NaN
# 1    Ukraine  2021-02-25  ...                       0             NaN
# 2    Ukraine  2021-02-26  ...                       0             NaN
# 3    Ukraine  2021-02-27  ...                       0             NaN
# 4    Ukraine  2021-03-01  ...                       0             NaN
# ..       ...         ...  ...                     ...             ...
# 233  Ukraine  2021-10-27  ...                 7217383             NaN
# 234  Ukraine  2021-10-28  ...                 7292521             NaN
# 235  Ukraine  2021-10-29  ...                 7377032             NaN
# 236  Ukraine  2021-10-30  ...                 7421546             NaN
# 237  Ukraine  2021-10-31  ...                 7449818             NaN
#
# [238 rows x 7 columns]

# %%
Ukraine_df.boxplot(column=['total_vaccinations'])

# %%
Ukraine_df.plot.hist()
plt.ylim(0,250)
# Out:
# (0.0, 250.0)

# %% [markdown]
# #India Vaccination Data

# %%
India_df=pd.read_csv('/content/gdrive/MyDrive/103 Project/India.csv')

# %%
India_df
# Out:
#     location  ... total_boosters
# 0      India  ...            NaN
# 1      India  ...            NaN
# 2      India  ...            NaN
# 3      India  ...            NaN
# 4      India  ...            NaN
# ..       ...  ...            ...
# 278    India  ...            NaN
# 279    India  ...            NaN
# 280    India  ...            NaN
# 281    India  ...            NaN
# 282    India  ...            NaN
#
# [283 rows x 8 columns]

# %%
India_df.plot.hist()
plt.xlim(0,839357801)
plt.ylim(0,250)
# Out:
# (0.0, 250.0)

# %% [markdown]
# **Removed the source_url column from the dataframe as it just stores the same links to destination.**

# %%
India_df.drop('source_url', axis=1, inplace=True)

# %%
India_df.columns
# Out:
# Index(['location', 'date', 'vaccine', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters'],
#       dtype='object')

# %% [markdown]
# **Replacing the NaN values to 0**

# %%
India_df["total_boosters"].fillna("0", inplace = True)

# %%
India_df
# Out:
#     location        date  ... people_fully_vaccinated  total_boosters
# 0      India  2021-01-15  ...                       0               0
# 1      India  2021-01-16  ...                       0               0
# 2      India  2021-01-17  ...                       0               0
# 3      India  2021-01-18  ...                       0               0
# 4      India  2021-01-19  ...                       0               0
# ..       ...         ...  ...                     ...             ...
# 278    India  2021-10-31  ...               329088622               0
# 279    India  2021-11-01  ...               332073961               0
# 280    India  2021-11-02  ...               333272071               0
# 281    India  2021-11-03  ...               336557471               0
# 282    India  2021-11-04  ...               337749522               0
#
# [283 rows x 7 columns]

# %%
India_df.boxplot(column=['total_vaccinations'])

# %% [markdown]
# #US Vaccination Data

# %%
US_df=pd.read_csv('/content/gdrive/MyDrive/103 Project/US.csv')

# %%
US_df
# Out:
#            date  ...                                    vaccine
# 0    2020-12-13  ...                            Pfizer/BioNTech
# 1    2020-12-14  ...                            Pfizer/BioNTech
# 2    2020-12-15  ...                            Pfizer/BioNTech
# 3    2020-12-16  ...                            Pfizer/BioNTech
# 4    2020-12-17  ...                            Pfizer/BioNTech
# ..          ...  ...                                        ...
# 322  2021-10-31  ...  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 323  2021-11-01  ...  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 324  2021-11-02  ...  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 325  2021-11-03  ...  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 326  2021-11-04  ...  Johnson&Johnson, Moderna, Pfizer/BioNTech
#
# [327 rows x 8 columns]

# %% [markdown]
# **Removed the source_url column from the dataframe as it just stores the same links to destination.**

# %%
US_df.drop('source_url', axis=1, inplace=True)

# %%
US_df.columns
# Out:
# Index(['date', 'location', 'total_vaccinations', 'people_vaccinated',
#        'people_fully_vaccinated', 'total_boosters', 'vaccine'],
#       dtype='object')

# %%
US_df.boxplot(column=['total_vaccinations'])

# %%
US_df
# Out:
#            date  ...                                    vaccine
# 0    2020-12-13  ...                            Pfizer/BioNTech
# 1    2020-12-14  ...                            Pfizer/BioNTech
# 2    2020-12-15  ...                            Pfizer/BioNTech
# 3    2020-12-16  ...                            Pfizer/BioNTech
# 4    2020-12-17  ...                            Pfizer/BioNTech
# ..          ...  ...                                        ...
# 322  2021-10-31  ...  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 323  2021-11-01  ...  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 324  2021-11-02  ...  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 325  2021-11-03  ...  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 326  2021-11-04  ...  Johnson&Johnson, Moderna, Pfizer/BioNTech
#
# [327 rows x 7 columns]

# %%
US_df.plot.hist()
#Values in Millions
plt.xlim(0,522591394) 
print()

plt.show('date')

# %% [markdown]
# #Analysis Questions

# %% [markdown]
# Q1. How many people are fully and partially vaccinated by the latest date in all 4 countries?

# %% [markdown]
# **India:**

# %%
# check the unique values in vaccine column
India_df.vaccine.unique()
# Out:
# array(['Covaxin, Oxford/AstraZeneca',
#        'Covaxin, Oxford/AstraZeneca, Sputnik V'], dtype=object)

# %%
import seaborn as sns

# %%
sns.countplot(India_df['vaccine'])
plt.title("Total number of vaccine doses administered in India")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Total number of vaccine doses administered in India')

# %%
# describe the data
# Numerical values
numerical_features = [feature for feature in India_df.columns if India_df[feature].dtype != 'O']
print('Number of numerical variables: ', len(numerical_features))
# Out:
# Number of numerical variables:  3

# %%
India_df[numerical_features].head()
# Out:
#    total_vaccinations  people_vaccinated  people_fully_vaccinated
# 0                   0                  0                        0
# 1              191181             191181                        0
# 2              224301             224301                        0
# 3              454049             454049                        0
# 4              674835             674835                        0

# %%
India_df[numerical_features].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc246096210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc24608ee50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc2545f6e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc2543fbe90>]],
#       dtype=object)

# %%
India_df[numerical_features].hist(column = 'total_vaccinations')
plt.xlabel("Count in Billion")
plt.title("Total Vaccinations provided in India is 1077107323 Billion ")
column = India_df["total_vaccinations"]
max_value = column.max()
print(max_value)
# Out:
# 1077107323

# %%
India_df[numerical_features].hist(column = 'people_fully_vaccinated')
plt.xlabel("Count")
plt.title("People Full Vaccinated in India is 337749522 Billion ")
column = India_df["people_fully_vaccinated"]
max_value = column.max()
print(max_value)
# Out:
# 337749522

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.heatmap(India_df[numerical_features].corr(), vmin=1, vmax=1, annot=True)

# %%
# describe the data
# categorical values
categorical_features = [feature for feature in India_df.columns if India_df[feature].dtype == 'O']
print('Number of numerical variables: ', len(categorical_features))
# Out:
# Number of numerical variables:  4

# %%
India_df[categorical_features].head()
# Out:
#   location        date                      vaccine total_boosters
# 0    India  2021-01-15  Covaxin, Oxford/AstraZeneca              0
# 1    India  2021-01-16  Covaxin, Oxford/AstraZeneca              0
# 2    India  2021-01-17  Covaxin, Oxford/AstraZeneca              0
# 3    India  2021-01-18  Covaxin, Oxford/AstraZeneca              0
# 4    India  2021-01-19  Covaxin, Oxford/AstraZeneca              0

# %%
# converting the column date from string into datetime object
India_df.dtypes
# Out:
# location                   object
# date                       object
# vaccine                    object
# total_vaccinations          int64
# people_vaccinated           int64
# people_fully_vaccinated     int64
# total_boosters             object
# dtype: object

# %%
from datetime import datetime

# %%
India_df['date'] = India_df['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
India_df[numerical_features].describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated
# count        2.830000e+02       2.830000e+02             2.830000e+02
# mean         3.615130e+08       2.739400e+08             8.757301e+07
# std          3.373545e+08       2.425015e+08             9.657203e+07
# min          0.000000e+00       0.000000e+00             0.000000e+00
# 25%          6.040011e+07       5.155084e+07             8.849274e+06
# 50%          2.402819e+08       1.943260e+08             4.595591e+07
# 75%          6.011572e+08       4.657360e+08             1.354212e+08
# max          1.077107e+09       7.393578e+08             3.377495e+08

# %%
India_df[categorical_features].describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#        location  ... total_boosters
# count       283  ...            283
# unique        1  ...              1
# top       India  ...              0
# freq        283  ...            283
# first       NaN  ...            NaN
# last        NaN  ...            NaN
#
# [6 rows x 4 columns]

# %% [markdown]
# **Ukraine:**

# %%
Ukraine_df.shape
# Out:
# (238, 7)

# %%
Ukraine_df.dtypes
# Out:
# location                    object
# date                        object
# vaccine                     object
# total_vaccinations           int64
# people_vaccinated            int64
# people_fully_vaccinated      int64
# total_boosters             float64
# dtype: object

# %%
Ukraine_df.columns
# Out:
# Index(['location', 'date', 'vaccine', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters'],
#       dtype='object')

# %%
sns.countplot(Ukraine_df['vaccine'])
column = Ukraine_df["vaccine"]
max_value = column.max()
print(max_value)
# Out:
# Oxford/AstraZeneca, Sinovac, Pfizer/BioNTech
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Numerical features
numerical_features = [feature for feature in Ukraine_df.columns if Ukraine_df[feature].dtype != 'O']
print('Numer of numerical variable: ', len(numerical_features))
# Out:
# Numer of numerical variable:  4

# %%
Ukraine_df[numerical_features].head()
# Out:
#    total_vaccinations  ...  total_boosters
# 0                 159  ...             NaN
# 1                1338  ...             NaN
# 2                3051  ...             NaN
# 3                3141  ...             NaN
# 4                4905  ...             NaN
#
# [5 rows x 4 columns]

# %%
Ukraine_df[numerical_features].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc23ba174d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc23ba1fb10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc23b9bffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc23b981710>]],
#       dtype=object)

# %%
Ukraine_df[numerical_features].hist(column = 'people_vaccinated')
plt.xlabel("Count")
plt.ylabel("Total Population")
plt.title("People Vaccinated in UKRAINE 10245773 is Million ")
column = Ukraine_df["people_vaccinated"]
max_value = column.max()
print(max_value)
# Out:
# 10245773

# %%
Ukraine_df[numerical_features].hist(column = 'people_fully_vaccinated')
plt.xlabel("Count")
plt.ylabel("Total Population")
plt.title("People Fully Vaccinated in UKRAINE 7449818 is Million ")
column = Ukraine_df["people_fully_vaccinated"]
max_value = column.max()
print(max_value)
# Out:
# 7449818

# %%
Ukraine_df[numerical_features].hist(column = 'total_vaccinations')
plt.xlabel("Count")
plt.ylabel("Total Population")
plt.title("Total Vaccination provided in UKRAINE 17695591 is billion ")
column = Ukraine_df["total_vaccinations"]
max_value = column.max()
print(max_value)
# Out:
# 17695591

# %%
sns.heatmap(Ukraine_df[numerical_features].corr(), vmin=1, vmax=1, annot=True)

# %% [markdown]
# **US & Canada dataset:**

# %%
US_df.head()
# Out:
#          date       location  ...  total_boosters          vaccine
# 0  2020-12-13  United States  ...               0  Pfizer/BioNTech
# 1  2020-12-14  United States  ...               0  Pfizer/BioNTech
# 2  2020-12-15  United States  ...               0  Pfizer/BioNTech
# 3  2020-12-16  United States  ...               0  Pfizer/BioNTech
# 4  2020-12-17  United States  ...               0  Pfizer/BioNTech
#
# [5 rows x 7 columns]

# %%
US_df[numerical_features].hist(column = 'total_vaccinations')
plt.xlabel("Count")
plt.ylabel("Total Population")
plt.title("Total Vaccination provided in US 426728092 is billion ")
column = US_df["total_vaccinations"]
max_value = column.max()
print(max_value)
# Out:
# 426728092

# %%
Canada_df[numerical_features].hist(column = 'total_vaccinations')
plt.xlabel("Count")
plt.ylabel("Total Population")
plt.title("Total Vaccination provided in Canada 58663274 is billion ")
column = Canada_df["total_vaccinations"]
max_value = column.max()
print(max_value)
# Out:
# 58663274

# %% [markdown]
# Q2. Types of vaccines administered in all countries?

# %% [markdown]
# **Canada:**

# %%
wordCloud = WordCloud(
    background_color='brown',
    max_font_size = 40).generate(' '.join(Canada_df.vaccine))
plt.figure(figsize=(15,7))
plt.axis('off')
plt.imshow(wordCloud)
plt.show()

# %% [markdown]
# **Ukraine:**

# %%
wordCloud = WordCloud(
    background_color='brown',
    max_font_size = 40).generate(' '.join(Ukraine_df.vaccine))
plt.figure(figsize=(15,7))
plt.axis('off')
plt.imshow(wordCloud)
plt.show()

# %% [markdown]
# **India:**

# %%
wordCloud = WordCloud(
    background_color='brown',
    max_font_size = 40).generate(' '.join(India_df.vaccine))
plt.figure(figsize=(15,7))
plt.axis('off')
plt.imshow(wordCloud)
plt.show()

# %% [markdown]
# **US:**

# %%
wordCloud = WordCloud(
    background_color='brown',
    max_font_size = 40).generate(' '.join(US_df.vaccine))
plt.figure(figsize=(15,7))
plt.axis('off')
plt.imshow(wordCloud)
plt.show()
